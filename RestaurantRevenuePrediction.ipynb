# %%
#importing libs
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import datetime as dt
# Out:
# C:\Users\shriya\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#reading data
trainData = pd.read_csv('train.csv')
testData = pd.read_csv('test.csv')

# %%
#formating data
testData['Open Date'] = pd.to_datetime(testData['Open Date'], format='%m/%d/%Y')
trainData['Open Date'] = pd.to_datetime(trainData['Open Date'], format='%m/%d/%Y')

#converting date to days from today
NOW=dt.datetime(2018,12,30)
dateLastTrain = pd.DataFrame({'Date':np.repeat([NOW],[len(trainData)]) })
dateLastTrain['Date'] = pd.to_datetime(dateLastTrain['Date'], format='%m/%d/%Y')  
dateLastTest = pd.DataFrame({'Date':np.repeat([NOW],[len(testData)]) })
dateLastTest['Date'] = pd.to_datetime(dateLastTest['Date'], format='%m/%d/%Y')  

trainData['OpenDays'] = dateLastTrain['Date'] - trainData['Open Date']
testData['OpenDays'] = dateLastTest['Date'] - testData['Open Date']

trainData['OpenDays'] = trainData['OpenDays'].astype('timedelta64[D]').astype(int)
testData['OpenDays'] = testData['OpenDays'].astype('timedelta64[D]').astype(int)

#drop open date
trainData = trainData.drop('Open Date', axis=1)
testData = testData.drop('Open Date', axis=1)

# %%
trainData.describe()
# Out:
#                Id          P1          P2          P3          P4          P5  \
# count  137.000000  137.000000  137.000000  137.000000  137.000000  137.000000
# mean    68.000000    4.014599    4.408759    4.317518    4.372263    2.007299
# std     39.692569    2.910391    1.514900    1.032337    1.016462    1.209620
# min      0.000000    1.000000    1.000000    0.000000    3.000000    1.000000
# 25%     34.000000    2.000000    4.000000    4.000000    4.000000    1.000000
# 50%     68.000000    3.000000    5.000000    4.000000    4.000000    2.000000
# 75%    102.000000    4.000000    5.000000    5.000000    5.000000    2.000000
# max    136.000000   12.000000    7.500000    7.500000    7.500000    8.000000
#
#                P6          P7          P8          P9     ...       \
# count  137.000000  137.000000  137.000000  137.000000     ...
# mean     3.357664    5.423358    5.153285    5.445255     ...
# std      2.134235    2.296809    1.858567    1.834793     ...
# min      1.000000    1.000000    1.000000    4.000000     ...
# 25%      2.000000    5.000000    4.000000    4.000000     ...
# 50%      3.000000    5.000000    5.000000    5.000000     ...
# 75%      4.000000    5.000000    5.000000    5.000000     ...
# max     10.000000   10.000000   10.000000   10.000000     ...
#
#               P30         P31         P32         P33         P34         P35  \
# count  137.000000  137.000000  137.000000  137.000000  137.000000  137.000000
# mean     2.729927    1.941606    2.525547    1.138686    2.489051    2.029197
# std      5.536647    3.512093    5.230117    1.698540    5.165093    3.436272
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      4.000000    3.000000    3.000000    2.000000    3.000000    4.000000
# max     25.000000   15.000000   25.000000    6.000000   24.000000   15.000000
#
#               P36         P37       revenue     OpenDays
# count  137.000000  137.000000  1.370000e+02   137.000000
# mean     2.211679    1.116788  4.453533e+06  3570.262774
# std      4.168211    1.790768  2.576072e+06  1471.257507
# min      0.000000    0.000000  1.149870e+06  1800.000000
# 25%      0.000000    0.000000  2.999068e+06  2566.000000
# 50%      0.000000    0.000000  3.939804e+06  3232.000000
# 75%      3.000000    2.000000  5.166635e+06  4047.000000
# max     20.000000    8.000000  1.969694e+07  8271.000000
#
# [8 rows x 40 columns]

# %%
testData.describe()
# Out:
#                   Id             P1             P2             P3  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    49999.500000       4.088030       4.428085       4.215325
# std     28867.657797       2.812963       1.428865       0.842161
# min         0.000000       1.000000       1.000000       0.000000
# 25%     24999.750000       2.000000       3.750000       4.000000
# 50%     49999.500000       3.000000       5.000000       4.000000
# 75%     74999.250000       4.000000       5.000000       4.000000
# max     99999.000000      15.000000       7.500000       6.000000
#
#                   P4             P5             P6            P7  \
# count  100000.000000  100000.000000  100000.000000  100000.00000
# mean        4.396025       1.989590       2.881900       5.30051
# std         1.035827       1.065314       1.531429       2.17858
# min         2.000000       1.000000       1.000000       1.00000
# 25%         4.000000       1.000000       2.000000       5.00000
# 50%         4.000000       2.000000       2.000000       5.00000
# 75%         5.000000       2.000000       4.000000       5.00000
# max         7.500000       6.000000      10.000000      10.00000
#
#                  P8             P9      ...                  P29  \
# count  100000.00000  100000.000000      ...        100000.000000
# mean        4.93100       5.251380      ...             3.084000
# std         1.71849       1.702632      ...             1.783927
# min         1.00000       4.000000      ...             0.000000
# 25%         4.00000       4.000000      ...             2.000000
# 50%         5.00000       5.000000      ...             3.000000
# 75%         5.00000       5.000000      ...             3.000000
# max        10.00000      10.000000      ...            10.000000
#
#                  P30            P31            P32            P33  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        2.083300       1.193330       1.942640       0.987430
# std         4.309479       2.307944       3.971298       1.534808
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         3.000000       1.000000       3.000000       2.000000
# max        25.000000      15.000000      25.000000       6.000000
#
#                  P34            P35            P36            P37  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        2.108670       1.832830       1.968890       0.973500
# std         4.685414       3.228769       3.805773       1.677267
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         3.000000       4.000000       3.000000       2.000000
# max        30.000000      15.000000      20.000000       8.000000
#
#             OpenDays
# count  100000.000000
# mean     3744.842800
# std      1749.439393
# min      1821.000000
# 25%      2461.000000
# 50%      3229.000000
# 75%      4306.000000
# max      8637.000000
#
# [8 rows x 39 columns]

# %%
citygroupDummy = pd.get_dummies(trainData['City Group'])
trainData = trainData.join(citygroupDummy)

citygroupDummyTest = pd.get_dummies(testData['City Group'])
testData = testData.join(citygroupDummyTest)

trainData = trainData.drop('City Group', axis=1)
testData = testData.drop('City Group', axis=1)

# %%
xTrain = pd.DataFrame({'OpenDays':trainData['OpenDays'].apply(np.log),
                      'Big Cities':trainData['Big Cities'], 'Other':trainData['Other'],
                      'P2':trainData['P2'], 'P8':trainData['P8'], 'P22':trainData['P22'],
                      'P24':trainData['P24'], 'P28':trainData['P28'], 'P26':trainData['P26']})
yTrain = trainData['revenue'].apply(np.log)

# %%
xTest = pd.DataFrame({'OpenDays':testData['OpenDays'].apply(np.log),
                      'Big Cities':testData['Big Cities'], 'Other':testData['Other'],
                      'P2':testData['P2'], 'P8':testData['P8'], 'P22':testData['P22'],
                      'P24':testData['P24'], 'P28':testData['P28'], 'P26':testData['P26']})

# %%
#Do Regression
model = RandomForestRegressor(n_estimators = 170)
model.fit(xTrain,yTrain)
pred = model.predict(xTest)
print(pred)
pred = np.exp(pred)
model.score(xTrain,yTrain)
# Out:
# [15.10386224 14.94151639 14.64071491 ... 14.78143325 14.90713461
#  15.42221765]
# 0.8721132554016955

# %%
testData = pd.read_csv("test.csv")
submission = pd.DataFrame({
        "Id": testData["Id"],
        "Prediction": pred
    })
submission.to_csv('RandomForestSimple.csv',header=True, index=False)
